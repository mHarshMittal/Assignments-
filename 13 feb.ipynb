# %% [raw]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.
# Q2. Write a python program to print Python Exception Hierarchy.
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
# Q5. Explain ImportError. What is ModuleNotFoundError?
# Q6. List down some best practices for exception handling in python.

# %% [raw]
# Q1. Explain Why We Have to Use the Exception Class While Creating a Custom Exception
# When creating a custom exception in Python, you should inherit from the Exception class because:
#
# Consistency: All exceptions in Python derive from Exception, so inheriting from it ensures that your custom exception behaves consistently with built-in exceptions.
# Functionality: The Exception class provides the foundational methods and attributes that exceptions use, such as __init__() and __str__(), for managing and displaying error messages.

# %% [raw]
# Ques 2

# %%
import traceback

def print_exception_hierarchy(exception_class, indent=0):
    """Recursively prints the hierarchy of exceptions."""
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print("Python Exception Hierarchy:")
print_exception_hierarchy(Exception)
# Out:
# Python Exception Hierarchy:
# Exception
#     TypeError
#         FloatOperation
#         MultipartConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#         ModuleNotFoundError
#         ZipImportError
#     OSError
#         ConnectionError
#             BrokenPipeError
#             ConnectionAbortedError
#             ConnectionRefusedError
#             ConnectionResetError
#                 RemoteDisconnected
#         BlockingIOError
#         ChildProcessError
#         FileExistsError
#         FileNotFoundError
#         IsADirectoryError
#         NotADirectoryError
#         InterruptedError
#             InterruptedSystemCall
#         PermissionError
#         ProcessLookupError
#         TimeoutError
#         UnsupportedOperation
#         itimer_error
#         herror
#         gaierror
#         SSLError
#             SSLCertVerificationError
#             SSLZeroReturnError
#             SSLWantWriteError
# ...

# %% [raw]
# Zero division error

# %%
try:
    result = 10 / 0
except ZeroDivisionError as e:
    print("Error:", e)
# Out:
# Error: division by zero

# %% [raw]
# overflow

# %%
try:
    result = 1e308 * 1e308  # Large number that causes overflow
except OverflowError as e:
    print("Error:", e)

# %% [raw]
# The LookupError class is used as a base class for errors raised when a lookup operation fails. It helps in catching exceptions related to indexing or key retrieval.
#
# KeyError: Raised when a dictionary key is not found.

# %%
my_dict = {"name": "Alice"}
try:
    value = my_dict["age"]
except KeyError as e:
    print("KeyError:", e)
# Out:
# KeyError: 'age'

# %%
my_list = [1, 2, 3]
try:
    value = my_list[5]
except IndexError as e:
    print("IndexError:", e)
# Out:
# IndexError: list index out of range

# %% [raw]
# Q5. Explain ImportError. What is ModuleNotFoundError?
# ImportError: Raised when an import statement fails to find the module or its components.
#
# ModuleNotFoundError: A subclass of ImportError, raised specifically when a module cannot be found.

# %%
try:
    import non_existent_module
except ImportError as e:
    print("ImportError:", e)
# Out:
# ImportError: No module named 'non_existent_module'

# %% [raw]
# Ques 6

# %%
try:
    # code
except ValueError:
    # handle ValueError
# Out:
#   Cell In[7], line 3
#     except ValueError:
#     ^
# IndentationError: expected an indented block after 'try' statement on line 1

# %%
try:
    file = open('file.txt')
    # process file
finally:
    file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 try:
# ----> 2     file = open('file.txt')
#       3     # process file
#       4 finally:
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.txt'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2     file = open('file.txt')
# ...

# %%
try:
    # code
except ValueError as e:
    # handle exception
    raise  # Re-raises the caught exception
# Out:
#   Cell In[9], line 3
#     except ValueError as e:
#     ^
# IndentationError: expected an indented block after 'try' statement on line 1
