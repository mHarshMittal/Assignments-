# %% [raw]
# ### Q1: What are the three measures of central tendency?
#
# The three measures of central tendency are:
# 1. **Mean**: The average of all data points.
# 2. **Median**: The middle value when data points are sorted in ascending order.
# 3. **Mode**: The most frequently occurring value in the dataset.
#
#
# ### Q2: Difference between Mean, Median, and Mode
#
# - **Mean**: Calculated by summing all values and dividing by the number of values. It provides a measure of the "center" of the data but can be affected by outliers.
# - **Median**: The middle value when the dataset is ordered. It is less affected by outliers and skewed data, giving a better measure of central location in such cases.
# - **Mode**: The value that appears most frequently. It is useful for categorical data and can have multiple modes.
#
# ### Q3: Measures of Central Tendency for the Given Height Data
#
#
#
# Given data: `[178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5]`
#
# **Mean**:
# \[
# \text{Mean} = \frac{\sum \text{data}}{\text{number of data points}} = \frac{178 + 177 + 176 + 177 + 178.2 + 178 + 175 + 179 + 180 + 175 + 178.9 + 176.2 + 177 + 172.5 + 178 + 176.5}{16} \approx 177.31
# \]
#
# **Median**:
# Sorted data: `[172.5, 175, 175, 176, 176.2, 176.5, 177, 177, 177, 178, 178, 178, 178.2, 178.9, 179, 180]`
# Median = Average of 8th and 9th values: \((177 + 177) / 2 = 177\)
#
# **Mode**:
# The value that appears most frequently is 177, so the mode is 177.
#
# ### Q4: Standard Deviation for the Given Data
#
# **Formula**:
# \[
# \text{Standard Deviation} = \sqrt{\frac{\sum (x_i - \text{mean})^2}{n - 1}}
# \]
#
# Using the given data:
# Mean = 177.31
#
# Calculate variance:
# \[
# \text{Variance} = \frac{\sum (x_i - 177.31)^2}{15} \approx 5.24
# \]
#
# Standard deviation:
# \[
# \text{Standard Deviation} = \sqrt{5.24} \approx 2.29
# \]
#
# ### Q5: Measures of Dispersion
#
# **Range**: Difference between the maximum and minimum values. It shows the span of the dataset.
# **Variance**: Average of the squared differences from the mean. It quantifies the spread of the data.
# **Standard Deviation**: Square root of variance. It gives the average distance of data points from the mean.
#
# **Example**:
# For dataset `[10, 12, 23, 23, 16, 23, 21, 16]`:
# - Range = 23 - 10 = 13
# - Variance = \(\frac{((10-18.125)^2 + (12-18.125)^2 + \ldots)}{7} = 20.3\)
# - Standard Deviation = \(\sqrt{20.3} \approx 4.51\)
#
# ### Q6: What is a Venn Diagram?
#
# A Venn diagram is a graphical representation of sets and their relationships. It uses overlapping circles to show how different sets intersect, union, or complement each other.
#
# ### Q7: Set Operations
#
# Given sets:
# - \( A = \{2, 3, 4, 5, 6, 7\} \)
# - \( B = \{0, 2, 6, 8, 10\} \)
#
# (i) **Intersection** (\( A \cap B \)):
# \[
# A \cap B = \{2, 6\}
# \]
#
# (ii) **Union** (\( A \cup B \)):
# \[
# A \cup B = \{0, 2, 3, 4, 5, 6, 7, 8, 10\}
# \]
#
# ### Q8: What is Skewness in Data?
#
# Skewness measures the asymmetry of the distribution of data around its mean. Positive skew (right-skewed) indicates a longer right tail, while negative skew (left-skewed) indicates a longer left tail.
#
# ### Q9: Position of Median in Right-Skewed Data
#
# In right-skewed data, the median is typically less than the mean. The mean is pulled towards the right tail, making it greater than the median.
#
# ### Q10: Covariance vs. Correlation
#
# - **Covariance**: Measures how two variables change together. Positive covariance indicates they move in the same direction, while negative indicates opposite directions.
# - **Correlation**: Normalized form of covariance that measures the strength and direction of a linear relationship between two variables. Ranges from -1 to 1.
#
# ### Q11: Formula for Sample Mean
#
# **Formula**:
# \[
# \text{Sample Mean} = \frac{\sum x_i}{n}
# \]
#
# **Example**:
# For dataset `[4, 8, 6, 5, 7]`:
# \[
# \text{Mean} = \frac{4 + 8 + 6 + 5 + 7}{5} = 6
# \]
#
# ### Q12: Measures of Central Tendency in Normal Distribution
#
# For a normal distribution, the mean, median, and mode are all equal and located at the center of the distribution.
#
# ### Q13: Covariance vs. Correlation
#
# **Covariance**:
# - Measures direction of relationship.
# - Units are the product of the units of the two variables.
#
# **Correlation**:
# - Measures strength and direction of relationship.
# - Unitless, ranging from -1 to 1.
#
# ### Q14: Effect of Outliers on Measures of Central Tendency and Dispersion
#
# **Mean**: Outliers can skew the mean significantly.
# **Median**: Less affected by outliers, remains more stable.
# **Standard Deviation**: Outliers increase variance and standard deviation.
#
# **Example**:
# For data `[10, 12, 14, 100]`:
# - Mean = 34, heavily skewed by the outlier 100.
# - Median = 13, less affected.
# - Standard Deviation = 39.5, increased by the outlier.
